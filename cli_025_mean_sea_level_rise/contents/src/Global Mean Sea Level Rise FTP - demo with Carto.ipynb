# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#import requests as req
import urllib.request as req
import shutil
from contextlib import closing


# Authentication
from configparser import ConfigParser

config = ConfigParser()
config.read("/Users/nathansuberi/Desktop/Code Portfolio/ResourceWatchCode/.env")
# FROM: https://resourcewatch.carto.com/u/wri-rw/your_apps
carto_api_token = config.get("auth", "carto_api_token")

# import seaborn as sns
plt.style.use('ggplot')
% matplotlib inline

# %%
# Read the files that are on the FTP
ftp = "ftp://podaac.jpl.nasa.gov/allData/merged_alt/L2/TP_J1_OSTM/global_mean_sea_level/"
df = pd.DataFrame(req.urlopen(ftp).read().splitlines())
df["files"] = df[0].str.split(expand=True)[8].astype(str)
print(df["files"])
df["files"] = df["files"].apply(lambda row: row[2:-1])

# Select the file that contains the data... i.e. ends with .txt, and has "V4" in the name
data_file_index = df["files"].apply(lambda row: row.endswith(".txt") & ("V4" in row))
print(data_file_index)

# Pull out just the file name
remote_file_name = df.loc[data_file_index,"files"].values[0]
remote_file_name
# Out:
# 0                  b'GMSL_TPJAOS_V4.jpg'
# 1    b'GMSL_TPJAOS_V4_199209_201708.txt'
# 2     b'README_GMSL_folder_contents.txt'
# Name: files, dtype: object
# 0    False
# 1     True
# 2    False
# Name: files, dtype: bool
# 'GMSL_TPJAOS_V4_199209_201708.txt'

# %%
sea_level = pd.read_csv(ftp+remote_file_name, header = None, sep = '\t')
sea_level
# Out:
#                                                      0
# 0                       HDR Global Mean Sea Level Data
# 1                                                  HDR
# 2    HDR This file contains Global Mean Sea Level (...
# 3    HDR auspices of the NASA MEaSUREs program. The...
# 4    HDR Climate Research (http://podaac.jpl.nasa.g...
# 5    HDR TOPEX/Poseidon, Jason-1 and OSTM/Jason-2 t...
# 6    HDR geophysical corrections applied and placed...
# 7         HDR time, regardless of the instrument used.
# 8                                                  HDR
# 9    HDR The data can be found below. A separate fi...
# 10   HDR column 12 below) with the 60-day Gaussian ...
# 11                HDR and semi-annual signals removed.
# 12                                                 HDR
# 13              HDR If you use these data please cite:
# 14   HDR GSFC. 2015. Global Mean Sea Level Trend fr...
# 15   HDR Jason-2 Version 3. Ver. 3. PO.DAAC, CA, US...
# 16                                                 HDR
# 17   HDR For information on how the data were gener...
# 18   HDR B. D. Beckley, N. P. Zelensky, S. A. Holme...
# 19   HDR of the Jason-2 Extension to the TOPEX/Pose...
# 20   HDR Monitoring, Marine Geodesy, Vol 33, Suppl ...
# 21                                                 HDR
# 22                            HDR ====================
# 23                                                 HDR
# 24   HDR Global Mean Sea Level (GMSL) variations fr...
# 25                                                 HDR
# 26                             HDR column description
# 27   HDR 1 altimeter type 0=dual-frequency  999=sin...
# 28                          HDR 2 merged file cycle #
# 29            HDR 3 year+fraction of year (mid-cycle)
# ..                                                 ...
# 919     0 887  2016.7932129    469591 343936.19    ...
# 920     0 888  2016.8203125    467317 340722.31    ...
# 921     0 889  2016.8474121    469138 342933.50    ...
# 922     0 890  2016.8745117    472052 343185.31    ...
# 72      0  39  1993.7722168    452877 332728.09    ...
# 73      0  40  1993.7993164    454650 332592.41    ...
# 75      0  42  1993.8536377    463414 337651.69    ...
# 76      0  43  1993.8808594    462117 335541.59    ...
# ..                                                 ...
# 919     0 887  2016.7932129    469591 343936.19    ...
# 920     0 888  2016.8203125    467317 340722.31    ...
# 921     0 889  2016.8474121    469138 342933.50    ...
# 922     0 890  2016.8745117    472052 343185.31    ...
# 923     0 891  2016.9016113    478495 346453.91    ...
# 924     0 892  2016.9287109    412712 297914.19    ...
# 925     0 893  2016.9558105    480846 346842.09    ...
# 926     0 894  2016.9827881    480430 347839.59    ...
# 927     0 895  2017.0100098    485347 349233.19    ...
# 928     0 896  2017.0371094    482567 347264.31    ...
# 929     0 897  2017.0643311    479200 344826.31    ...
# 930     0 898  2017.0914307    479859 345492.69    ...
# 931     0 899  2017.1186523    478434 344268.50    ...
# 932     0 900  2017.1457520    479643 344784.50    ...
# 933     0 901  2017.1729736    483270 347856.00    ...
# 934     0 902  2017.2000732    476093 343366.59    ...
# 935     0 903  2017.2272949    476915 343784.59    ...
# 936     0 904  2017.2545166    475783 343274.31    ...
# 937     0 905  2017.2816162    478451 344591.19    ...
# 938     0 906  2017.3088379    475213 341897.00    ...
# 939     0 907  2017.3359375    479329 344718.41    ...
# 940     0 908  2017.3631592    483975 348429.41    ...
# 941     0 909  2017.3902588    480876 346277.59    ...
# 942     0 910  2017.4174805    478509 345081.00    ...
# 943     0 911  2017.4445801    475488 343148.69    ...
# 944     0 912  2017.4718018    477892 345091.59    ...
# 945     0 913  2017.4989014    475148 344423.19    ...
# 946     0 914  2017.5261230    475941 346022.59    ...
# 947     0 915  2017.5533447    469873 343282.19    ...
# 948     0 916  2017.5804443    465825 342386.69    ...
#
# [840 rows x 1 columns]

# %%
# Goal:
# To convert all multi-space breaks in between numbers into single space breaks
test = df.loc[50,0]
test.split()
# Out:
# ['0',
#  '17',
#  '1993.1745605',
#  '467982',
#  '337063.59',
#  '-38.86',
#  '96.18',
#  '-39.56',
#  '-38.82',
#  '96.17',
#  '-39.52',
#  '-37.63']

# %%
#create columns if there's a space
pretty=df[0].str.split(expand=True)
#pretty.columns =["altimeter type, 0=dual-frequency  999=single frequency","merged file cycle #","year+fraction of year (mid-cycle)", "number of observations", "number of weighted observations", "GMSL (Global Isostatic Adjustment (GIA) not applied) variation (mm) with respect to TOPEX collinear mean reference","standard deviation of GMSL (GIA not applied) variation estimate (mm) HDR", "smoothed (60-day Gaussian type filter) GMSL (GIA not applied) variation (mm)", "GMSL (Global Isostatic Adjustment (GIA) applied) variation (mm) with respect to TOPEX collinear mean reference", "standard deviation of GMSL (GIA applied) variation estimate (mm)", "smoothed (60-day Gaussian type filter) GMSL (GIA applied) variation (mm)", "smoothed (60-day Gaussian type filter) GMSL (GIA applied) variation (mm); annual and semi-annual signal removed"]
pretty
# Out:
#     0    1             2       3          4       5       6       7       8   \
# 73    91.08  -32.75  -38.31
# 75    91.17  -33.95  -38.97
# 76    91.77  -34.47  -38.89
# ..      ...     ...     ...
# 919  100.58   48.38   42.82
# 920   99.60   49.21   43.74
# 921  100.23   49.84   44.71
# 922   98.80   50.01   45.43
# 923   98.17   49.56   45.70
# 924   94.21   48.53   45.49
# 925   92.86   47.16   44.98
# 926   92.07   45.70   44.36
# 927   89.60   44.34   43.78
# 928   90.40   43.14   43.26
# 929   89.71   42.15   42.82
# 930   88.98   41.48   42.59
# 931   91.75   41.20   42.64
# 932   90.14   41.30   42.98
# 933   91.61   41.68   43.56
# 934   94.19   42.17   44.23
# 935   96.08   42.58   44.84
# 936   95.79   42.74   45.24
# 937   94.05   42.55   45.33
# 938   94.38   42.05   45.15
# 939   92.15   41.40   44.83
# 940   90.80   40.83   44.57
# 941   89.54   40.53   44.53
# 942   92.06   40.56   44.70
# 943   91.53   40.97   45.10
# 944   91.07   41.43   45.36
# 945   92.21   41.85   45.37
# 946   91.98   42.19   45.09
# 947   92.13   42.43   44.50
# 948   95.60   42.61   43.68
#
# [840 rows x 12 columns]

# %%
import cartoframes
# `base_url`s are of the form `http://{username}.carto.com/` for most users
USERNAME="wri-rw"
cc = cartoframes.CartoContext(base_url='http://{username}.carto.com/'.format(username=USERNAME),
                              api_key=carto_api_token)
cc.write(pretty, 'Global Mean Sea Level Rise')
# Out:
# /Users/nathansuberi/.pyenv/versions/3.6.0/lib/python3.6/site-packages/carto/auth.py:53: UserWarning: You are using unencrypted API key                           authentication!!!
#   authentication!!!")
# /Users/nathansuberi/.pyenv/versions/3.6.0/lib/python3.6/site-packages/cartoframes/context.py:241: UserWarning: Table will be named `global_mean_sea_level_rise`
#   warn('Table will be named `{}`'.format(table_name))
# The following columns were changed in the CARTO copy of this dataframe:
# 0 -> _0
# 1 -> _1
# 2 -> _2
# 3 -> _3
# 4 -> _4
# 5 -> _5
# 6 -> _6
# 7 -> _7
# 8 -> _8
# 9 -> _9
# 10 -> _10
# 11 -> _11
# ----------------------------------------------------------------
# KeyError                       Traceback (most recent call last)
# <ipython-input-107-a0017a64e14e> in <module>()
#       4 cc = cartoframes.CartoContext(base_url='http://{username}.carto.com/'.format(username=USERNAME),
#       5                               api_key=carto_api_token)
# ----> 6 cc.write(pretty, 'Global Mean Sea Level Rise')
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/site-packages/cartoframes/context.py in write(self, df, table_name, temp_dir, overwrite, lnglat, encode_geom, geom_col, **kwargs)
#     253             final_table_name = self._send_dataframe(_df, table_name, temp_dir,
#     254                                                     geom_col, pgcolnames,
# --> 255                                                     kwargs)
#     256             self._set_schema(_df, final_table_name, pgcolnames)
#     257
#
# ~/.pyenv/versions/3.6.0/lib/python3.6/site-packages/cartoframes/context.py in _send_dataframe(self, df, table_name, temp_dir, geom_col, pgcolnames, kwargs)
#     461                 remove_tempfile(tempfile)
#     462                 raise CartoException('Failed to send DataFrame')
# --> 463             import_id = res['item_queue_id']
#     464
#     465         remove_tempfile(tempfile)
#
# KeyError: 'item_queue_id'
